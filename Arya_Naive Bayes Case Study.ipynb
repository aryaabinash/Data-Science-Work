# %% [markdown]
# Human Activity Recognisation Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# IMport data
training = pd.read_csv('har_train.csv')
test = pd.read_csv('har_validate.csv')

# %%
training.shape
# Out:
# (13737, 53)

# %%
training.head()
# Out:
#   classe  roll_belt  pitch_belt  yaw_belt  total_accel_belt  gyros_belt_x  \
# 0      A       1.41        8.07     -94.4                 3          0.00
# 1      A       1.41        8.07     -94.4                 3          0.02
# 2      A       1.42        8.07     -94.4                 3          0.00
# 3      A       1.48        8.05     -94.4                 3          0.02
# 4      A       1.45        8.06     -94.4                 3          0.02
#
#    gyros_belt_y  gyros_belt_z  accel_belt_x  accel_belt_y  ...  \
# 0           0.0         -0.02           -21             4  ...
# 1           0.0         -0.02           -22             4  ...
# 2           0.0         -0.02           -20             5  ...
# 3           0.0         -0.03           -22             3  ...
# 4           0.0         -0.02           -21             4  ...
#
#    total_accel_forearm  gyros_forearm_x  gyros_forearm_y  gyros_forearm_z  \
# 0                   36             0.03             0.00            -0.02
# 1                   36             0.02             0.00            -0.02
# 2                   36             0.03            -0.02             0.00
# 3                   36             0.02            -0.02             0.00
# 4                   36             0.02            -0.02            -0.03
#
#    accel_forearm_x  accel_forearm_y  accel_forearm_z  magnet_forearm_x  \
# 0              192              203             -215               -17
# 1              192              203             -216               -18
# 2              196              204             -213               -18
# 3              189              206             -214               -16
# 4              193              203             -215                -9
#
#    magnet_forearm_y  magnet_forearm_z
# 0               654               476
# 1               661               473
# 2               658               469
# 3               658               469
# 4               660               478
#
# [5 rows x 53 columns]

# %%
# Based on these above values you have to predict the class

# %%
training['classe'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E'], dtype=object)

# %%
#Split into x and y
x_train = training.drop('classe', axis =1)
y_train = training.loc[:,'classe']

x_test = test.drop('classe', axis =1)
y_test = test.loc[:,'classe']

# %%
x_train
# Out:
#        roll_belt  pitch_belt  yaw_belt  total_accel_belt  gyros_belt_x  \
# 0           1.41        8.07     -94.4                 3          0.00
# 1           1.41        8.07     -94.4                 3          0.02
# 2           1.42        8.07     -94.4                 3          0.00
# 3           1.48        8.05     -94.4                 3          0.02
# 4           1.45        8.06     -94.4                 3          0.02
# ...          ...         ...       ...               ...           ...
# 13732     154.00      -32.70     125.0                24          0.29
# 13733     154.00      -32.90     126.0                24          0.31
# 13734     145.00      -35.50     130.0                19          0.37
# 13735     143.00      -35.90     131.0                18          0.37
# 13736     143.00      -36.00     132.0                18          0.35
#
#        gyros_belt_y  gyros_belt_z  accel_belt_x  accel_belt_y  accel_belt_z  \
# 0              0.00         -0.02           -21             4            22
# 1              0.00         -0.02           -22             4            22
# 2              0.00         -0.02           -20             5            23
# 3              0.00         -0.03           -22             3            21
# 4              0.00         -0.02           -21             4            21
# ...             ...           ...           ...           ...           ...
# 13732          0.05         -0.36            67            51          -218
# 13733          0.05         -0.41            69            52          -217
# 13734          0.00         -0.64            47            13          -177
# 13735         -0.02         -0.59            46            18          -172
# 13736         -0.02         -0.57            42            25          -171
#
#        ...  total_accel_forearm  gyros_forearm_x  gyros_forearm_y  \
# 0      ...                   36             0.03             0.00
# 1      ...                   36             0.02             0.00
# 2      ...                   36             0.03            -0.02
# 3      ...                   36             0.02            -0.02
# 4      ...                   36             0.02            -0.02
# ...    ...                  ...              ...              ...
# 13732  ...                   32             1.36            -2.83
# 13733  ...                   31             1.33            -2.89
# 13734  ...                   29             1.54            -1.20
# 13735  ...                   32             1.48            -0.90
# 13736  ...                   33             1.38            -0.64
#
#        gyros_forearm_z  accel_forearm_x  accel_forearm_y  accel_forearm_z  \
# 0                -0.02              192              203             -215
# 1                -0.02              192              203             -216
# 2                 0.00              196              204             -213
# 3                 0.00              189              206             -214
# 4                -0.03              193              203             -215
# ...                ...              ...              ...              ...
# 13732            -0.61             -227              221                0
# 13733            -0.71             -230              200               -8
# 13734             0.05             -263              -99              -45
# 13735             0.05             -270             -141              -51
# 13736             0.08             -278             -159              -52
#
#        magnet_forearm_x  magnet_forearm_y  magnet_forearm_z
# 0                   -17               654               476
# 1                   -18               661               473
# 2                   -18               658               469
# 3                   -16               658               469
# 4                    -9               660               478
# ...                 ...               ...               ...
# 13732              -592               -85               431
# 13733              -571              -126               404
# 13734              -116              -654               -70
# 13735               -68              -678               -98
# 13736               -60              -686              -110
#
# [13737 rows x 52 columns]

# %%
# DO the Modelling

model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
train_pred = model.predict(x_train)

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array(['A', 'A', 'A', ..., 'E', 'E', 'E'], dtype='<U1')

# %%
from sklearn import metrics

print(metrics.confusion_matrix(pred,y_test, labels=["A","B","C","D","E"]))
# Out:
# [[1070  127  223  102   51]
#  [  95  685  106   35  239]
#  [ 262  145  512  271   95]
#  [ 212   76  136  441  143]
#  [  35  106   49  115  554]]

# %%
print(metrics.classification_report(pred,y_test, labels=["A","B","C","D","E"]))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.64      0.68      0.66      1573
#            B       0.60      0.59      0.60      1160
#            C       0.50      0.40      0.44      1285
#            D       0.46      0.44      0.45      1008
#            E       0.51      0.64      0.57       859
#
#     accuracy                           0.55      5885
#    macro avg       0.54      0.55      0.54      5885
# weighted avg       0.55      0.55      0.55      5885

# %%
# Hyperparameter tuning
"""
var_smoothing
# Out:
#   Cell In[21], line 2
#     """"
#     ^
# _IncompleteInputError: incomplete input
