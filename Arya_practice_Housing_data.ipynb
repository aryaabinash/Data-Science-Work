# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
"""
crim zn indus chas nox rm age dis rad tax ptratio b lstat price

formulla : y = B1*X1 + B2*X2+B3*X3+....+B0
Y = B1*X+B0/W1*X + W0
Price = w1*crim+w2*zn + w3*indus + w4*chas+ w5*nox+w6*rm...........
z"""
# Out:
# '\ncrim zn indus chas nox rm age dis rad tax ptratio b lstat price\n\nformulla : y = B1*X1 + B2*X2+B3*X3+....+B0\nY = B1*X+B0/W1*X + W0\nPrice = w1*crim+w2*zn + w3*indus + w4*chas+ w5*nox+w6*rm...........\nz'

# %%
df = pd.read_csv('BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#DUplicate data
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# Describe the dataset
df.describe().T.round(2)
# Out:
#          count    mean     std     min     25%     50%     75%     max
# crim     506.0    3.61    8.60    0.01    0.08    0.26    3.68   88.98
# zn       506.0   11.36   23.32    0.00    0.00    0.00   12.50  100.00
# indus    506.0   11.14    6.86    0.46    5.19    9.69   18.10   27.74
# chas     506.0    0.07    0.25    0.00    0.00    0.00    0.00    1.00
# nox      506.0    0.55    0.12    0.38    0.45    0.54    0.62    0.87
# rm       506.0    6.28    0.70    3.56    5.89    6.21    6.62    8.78
# age      506.0   68.57   28.15    2.90   45.02   77.50   94.07  100.00
# dis      506.0    3.80    2.11    1.13    2.10    3.21    5.19   12.13
# rad      506.0    9.55    8.71    1.00    4.00    5.00   24.00   24.00
# tax      506.0  408.24  168.54  187.00  279.00  330.00  666.00  711.00
# ptratio  506.0   18.46    2.16   12.60   17.40   19.05   20.20   22.00
# b        506.0  356.67   91.29    0.32  375.38  391.44  396.22  396.90
# ...

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# Skewness value
df.skew()
# Out:
# crim       5.223149
# zn         2.225666
# indus      0.295022
# chas       3.405904
# nox        0.729308
# rm         0.403612
# age       -0.598963
# dis        1.011781
# rad        1.004815
# tax        0.669956
# ptratio   -0.802325
# b         -2.890374
# lstat      0.906460
# medv       1.108098
# dtype: float64

# %%
# CHeck via boxplot
def boxplots(col):
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.show()
for i in list(df.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
# Correlation part
df.corr().round(2)
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis   rad   tax  ptratio  \
# crim     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# zn      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# indus    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# chas    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# nox      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# rm      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# age      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# dis     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# rad      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# tax      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# ptratio  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
# rm - 0.7 and lstat = -0.74

# %%
corr_matrix = df.corr().round(2)
corr_matrix[np.abs(corr_matrix)>0.7]
# Out:
#          crim   zn  indus  chas   nox   rm   age   dis   rad   tax  ptratio  \
# crim      1.0  NaN    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# zn        NaN  1.0    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# indus     NaN  NaN   1.00   NaN  0.76  NaN   NaN -0.71   NaN  0.72      NaN
# chas      NaN  NaN    NaN   1.0   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# nox       NaN  NaN   0.76   NaN  1.00  NaN  0.73 -0.77   NaN   NaN      NaN
# rm        NaN  NaN    NaN   NaN   NaN  1.0   NaN   NaN   NaN   NaN      NaN
# age       NaN  NaN    NaN   NaN  0.73  NaN  1.00 -0.75   NaN   NaN      NaN
# dis       NaN  NaN  -0.71   NaN -0.77  NaN -0.75  1.00   NaN   NaN      NaN
# rad       NaN  NaN    NaN   NaN   NaN  NaN   NaN   NaN  1.00  0.91      NaN
# tax       NaN  NaN   0.72   NaN   NaN  NaN   NaN   NaN  0.91  1.00      NaN
# ptratio   NaN  NaN    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      1.0
# ...

# %%
# Rule : No or little Multicolinearity: multicolineary occurs when independent varibale in regression model
# are highly correlated. This correlation can make it difficult to determine the individual effect of each
# independent variable on the dependent varibale. Ideally the model should have little or no mulitcolinearity
# idv can inflence other idv varible

# How will you check multcolinerity- VIF- Variance Inflation Factor >5

# %%
sns.heatmap(df.corr().round(2), annot = True, cmap='coolwarm')
plt.show()

# %%
# Preprocessing part

# %%
#1)Handling missing value
#2)ENcoding concept
#3)Outlier treatment
#4)Feature scaling

# %%
# No missing data found
df.isnull().sum().sum()
# Out:
# 0

# %%
# Encoding is not require
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
#Outlier treatment
# Crime, zn, rm, b, rm is not required as range is 3 to 8

# %%
df['crim'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64

# %%
Q1 = 0.08
Q3 = 3.67
IQR = Q3- Q1
upper_limit = Q3 + 1.5 * IQR
df['crim'] = np.where(df['crim']>upper_limit, upper_limit,df['crim'])

# %%
df['zn'].describe()
# Out:
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: zn, dtype: float64

# %%
Q1 = 0.00
Q3 = 12.50
IQR = Q3- Q1
upper_limit = Q3 + 1.5 * IQR
df['zn'] = np.where(df['zn']>upper_limit, upper_limit,df['zn'])

# %%
df['b'].describe()
# Out:
# count    506.000000
# mean     356.674032
# std       91.294864
# min        0.320000
# 25%      375.377500
# 50%      391.440000
# 75%      396.225000
# max      396.900000
# Name: b, dtype: float64

# %%
Q1 = 375.377
Q3 = 396.22
IQR = Q3- Q1
lower_limit = Q1 - 1.5 * IQR
df['b'] = np.where(df['zn']>lower_limit, lower_limit,df['b'])

# %%
def boxplots(col):
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.show()
for i in list(df.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
# Split the data in ind and dep varibale
x = df.drop(['medv'], axis=1)
y = df['medv']

# %%
x.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0 -593.53   4.98
# 1 -593.53   9.14
# 2 -593.53   4.03
# 3 -593.53   2.94
# 4 -593.53   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
# Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaler = scaler.fit_transform(x)
x_scaler = pd.DataFrame(x_scaler, columns
